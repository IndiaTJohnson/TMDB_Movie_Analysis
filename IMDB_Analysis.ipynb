# %%
#Create Folder

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Create new folder with os
import os
os.makedirs('Data/',exist_ok=True)

# %%
# Confirm folder was created and files added successfully
os.listdir("Data/")
# Out:
# ['title-akas-us-only.csv', 'title.basics.tsv.gz', 'title.ratings.tsv.gz']

# %%
#Read in title-akas-us-only.csv file
akas = pd.read_csv('Data/title-akas-us-only.csv', low_memory=False)

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1452564 entries, 0 to 1452563
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1452564 non-null  object
#  1   ordering         1452564 non-null  int64
#  2   title            1452564 non-null  object
#  3   region           1452564 non-null  object
#  4   language         1452564 non-null  object
#  5   types            1452564 non-null  object
#  6   attributes       1452564 non-null  object
#  7   isOriginalTitle  1452564 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 88.7+ MB

# %%
#Read in title.basics.tsv.gz file
basics = pd.read_csv('Data/title.basics.tsv.gz', sep='\t', low_memory=False)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10017011 entries, 0 to 10017010
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 687.8+ MB

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
filter_us_titles = basics['tconst'].isin(akas['titleId'])
basics = basics[filter_us_titles]
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
# ...

# %%
#Create dataframe that replaced \N values
df = basics.replace({'\\N':np.nan})

# %%
df
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
# ...

# %%
#Drop NaN values in runtimeMinutes and genres columns ONLY
df.dropna(subset = ['runtimeMinutes', 'genres'], inplace = True)

# %%
#Create filter for full length movies
filter_fullLength = df['titleType'] == 'movie'

# %%
# Exclude movies that aren't full length or straight to TV.
df = df[filter_fullLength]

# %%
#Convert startYear to a float
df['startYear'] = df['startYear'].astype(float)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_61524\285191974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['startYear'] = df['startYear'].astype(float)

# %%
#Create filter to only keep movies with startYears 2000-2022
filter_startYear = (df['startYear'] >= 2000) & (df['startYear'] <= 2022)

# %%
#Filter to only keep movies with startYears 2000-2022
df = df[filter_startYear]

# %%
#Create filter for documentaries
filter_documentaries = df['genres'].str.contains('Documentary')

# %%
# Exclude movies in the documentary category.
df = df[~filter_documentaries]

# %%
df
# Out:
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 86793     tt0088751     movie
# 93930     tt0096056     movie
# ...             ...       ...
# 10016149  tt9914942     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 86793                                     The Naked Monster
# 93930                                  Crime and Punishment
# ...                                                     ...
# 10016149                             Life Without Sara Amat
# 10016544                               The Last White Witch
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86979 entries, 34802 to 10016777
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86979 non-null  object
#  1   titleType       86979 non-null  object
#  2   primaryTitle    86979 non-null  object
#  3   originalTitle   86979 non-null  object
#  4   isAdult         86979 non-null  object
#  5   startYear       86979 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  86979 non-null  object
#  8   genres          86979 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.6+ MB

# %%
df.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34802  tt0035423     movie                                     Kate & Leopold
# 61114  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67666  tt0069049     movie                         The Other Side of the Wind
# 86793  tt0088751     movie                                  The Naked Monster
# 93930  tt0096056     movie                               Crime and Punishment
#
#                                    originalTitle isAdult  startYear endYear  \
# 34802                             Kate & Leopold       0     2001.0     NaN
# 61114  El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67666                 The Other Side of the Wind       0     2018.0     NaN
# 86793                          The Naked Monster       0     2005.0     NaN
# 93930                       Crime and Punishment       0     2002.0     NaN
#
# ...

# %%
#Save cleaned basics dataframe to a csv file in Data Folder
df.to_csv('Data/cleaned-basics.csv')

# %%
#Load in title ratings data

# %%
#Read in title.ratings.tsv.gz file
df_ratings = pd.read_csv('Data/title.ratings.tsv.gz', sep='\t', low_memory=False)

# %%
filter_basics = df_ratings['tconst'].isin(df['tconst'])

# %%
df_ratings = df_ratings[filter_basics]

# %%
df_ratings = df_ratings.replace({'\\N':np.nan})

# %%
df_ratings
# Out:
#             tconst  averageRating  numVotes
# 17961    tt0035423            6.4     87153
# 40764    tt0062336            6.4       175
# 46645    tt0069049            6.7      7754
# 63640    tt0088751            5.2       336
# 69953    tt0096056            5.6       846
# ...            ...            ...       ...
# 1331411  tt9914942            6.6       178
# 1331437  tt9915872            6.4         9
# 1331450  tt9916170            7.0         7
# 1331451  tt9916190            3.7       243
# 1331462  tt9916362            6.4      5422
#
# [71900 rows x 3 columns]

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71900 entries, 17961 to 1331462
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         71900 non-null  object
#  1   averageRating  71900 non-null  float64
#  2   numVotes       71900 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df_ratings.head()
# Out:
#           tconst  averageRating  numVotes
# 17961  tt0035423            6.4     87153
# 40764  tt0062336            6.4       175
# 46645  tt0069049            6.7      7754
# 63640  tt0088751            5.2       336
# 69953  tt0096056            5.6       846

# %%
#Save cleaned ratings dataframe to a csv file in Data Folder
df_ratings.to_csv('Data/cleaned-ratings.csv')
